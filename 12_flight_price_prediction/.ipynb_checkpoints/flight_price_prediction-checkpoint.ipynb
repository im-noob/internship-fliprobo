# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import joblib
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import PowerTransformer

# %%
df = pd.read_csv('flight_data___.csv')

# %%
df
# Out:
#       Unnamed: 0 flight_name  flight_id start_time end_time travel_time  \
# 0              0    Go First   G8 - 336      14:20    16:35      2h 15m
# 1              1    Go First   G8 - 392      12:45    15:00      2h 15m
# 2              2    Go First   G8 - 323      18:05    20:25      2h 20m
# 3              3    Go First   G8 - 717      16:45    21:25      4h 40m
# 4              4    Go First   G8 - 167      15:00    21:55      6h 55m
# ...          ...         ...        ...        ...      ...         ...
# 7029        7029      IndiGo   6E - 137      11:55    23:15     11h 20m
# 7030        7030      IndiGo   6E - 124      16:30    23:15      6h 45m
# 7031        7031      IndiGo  6E - 6738      13:10    23:15      10h 5m
# 7032        7032      IndiGo  6E - 6152      06:05    17:05         11h
# 7033        7033      IndiGo  6E - 2189      23:55    07:10      7h 15m
#
#                     stops    fare          source     destination
# 0                Non Stop   5,954       DEL-Delhi      BOM-Mumbai
# 1                Non Stop   5,954       DEL-Delhi      BOM-Mumbai
# 2                Non Stop   5,954       DEL-Delhi      BOM-Mumbai
# 3     1 stop at Ahmedabad   5,954       DEL-Delhi      BOM-Mumbai
# 4        1 stop at Ranchi   5,954       DEL-Delhi      BOM-Mumbai
# ...                   ...     ...             ...             ...
# 7029   2 Stops (SXR, DEL)  12,092       IXJ-Jammu  CJB-Coimbatore
# 7030      1 stop at Delhi  14,454       IXJ-Jammu  CJB-Coimbatore
# 7031      1 stop at Delhi  14,454       IXJ-Jammu  CJB-Coimbatore
# 7032     1 stop at Mumbai  10,782  CJB-Coimbatore    DED-Dehradun
# 7033      1 stop at Delhi  12,357  CJB-Coimbatore    DED-Dehradun
#
# [7034 rows x 10 columns]

# %%
df.shape
# Out:
# (7034, 10)

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# flight_name    object
# flight_id      object
# start_time     object
# end_time       object
# travel_time    object
# stops          object
# fare           object
# source         object
# destination    object
# dtype: object

# %%
# Removing index column
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#      flight_name  flight_id start_time end_time travel_time  \
# 0       Go First   G8 - 336      14:20    16:35      2h 15m
# 1       Go First   G8 - 392      12:45    15:00      2h 15m
# 2       Go First   G8 - 323      18:05    20:25      2h 20m
# 3       Go First   G8 - 717      16:45    21:25      4h 40m
# 4       Go First   G8 - 167      15:00    21:55      6h 55m
# ...          ...        ...        ...      ...         ...
# 7029      IndiGo   6E - 137      11:55    23:15     11h 20m
# 7030      IndiGo   6E - 124      16:30    23:15      6h 45m
# 7031      IndiGo  6E - 6738      13:10    23:15      10h 5m
# 7032      IndiGo  6E - 6152      06:05    17:05         11h
# 7033      IndiGo  6E - 2189      23:55    07:10      7h 15m
#
#                     stops    fare          source     destination
# 0                Non Stop   5,954       DEL-Delhi      BOM-Mumbai
# 1                Non Stop   5,954       DEL-Delhi      BOM-Mumbai
# 2                Non Stop   5,954       DEL-Delhi      BOM-Mumbai
# 3     1 stop at Ahmedabad   5,954       DEL-Delhi      BOM-Mumbai
# 4        1 stop at Ranchi   5,954       DEL-Delhi      BOM-Mumbai
# ...                   ...     ...             ...             ...
# 7029   2 Stops (SXR, DEL)  12,092       IXJ-Jammu  CJB-Coimbatore
# 7030      1 stop at Delhi  14,454       IXJ-Jammu  CJB-Coimbatore
# 7031      1 stop at Delhi  14,454       IXJ-Jammu  CJB-Coimbatore
# 7032     1 stop at Mumbai  10,782  CJB-Coimbatore    DED-Dehradun
# 7033      1 stop at Delhi  12,357  CJB-Coimbatore    DED-Dehradun
#
# [7034 rows x 9 columns]

# %%
df.isnull().sum().sum()
# Out:
# 777

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum().sum()/df.shape[0]
# Out:
# 0.1104634631788456

# %%
# Drop column with no data
df.dropna(inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['flight_name', 'flight_id', 'start_time', 'end_time', 'travel_time',
#        'stops', 'fare', 'source', 'destination'],
#       dtype='object')

# %%
df.head()
# Out:
#   flight_name flight_id start_time end_time travel_time                stops  \
# 0    Go First  G8 - 336      14:20    16:35      2h 15m             Non Stop
# 1    Go First  G8 - 392      12:45    15:00      2h 15m             Non Stop
# 2    Go First  G8 - 323      18:05    20:25      2h 20m             Non Stop
# 3    Go First  G8 - 717      16:45    21:25      4h 40m  1 stop at Ahmedabad
# 4    Go First  G8 - 167      15:00    21:55      6h 55m     1 stop at Ranchi
#
#     fare     source destination
# 0  5,954  DEL-Delhi  BOM-Mumbai
# 1  5,954  DEL-Delhi  BOM-Mumbai
# 2  5,954  DEL-Delhi  BOM-Mumbai
# 3  5,954  DEL-Delhi  BOM-Mumbai
# 4  5,954  DEL-Delhi  BOM-Mumbai

# %%
df.shape
# Out:
# (6923, 9)

# %%
# Changin config
pd.options.display.max_rows = 1000

# %%
df['flight_name'].value_counts()
# Out:
# Air India    3084
# IndiGo       1746
# Vistara      1401
# Go First      378
# SpiceJet      261
# Air Asia       53
# Name: flight_name, dtype: int64

# %%
df['flight_id'].value_counts()
# Out:
# AI - 516     86
# AI - 838     77
# AI - 424     71
# AI - 505     66
# AI - 573     65
# AI - 543     64
# AI - 501     62
# AI - 607     62
# AI - 809     59
# AI - 687     56
# UK - 878     56
# AI - 640     56
# AI - 806     55
# AI - 660     55
# AI - 867     54
# AI - 430     54
# AI - 559     54
# UK - 852     53
# AI - 635     53
# AI - 442     53
# AI - 888     51
# AI - 808     49
# AI - 541     48
# AI - 9894    48
# UK - 706     47
# AI - 804     47
# UK - 657     46
# AI - 440     43
# AI - 639     43
# AI - 503     41
# UK - 986     41
# AI - 840     40
# UK - 877     39
# UK - 854     39
# UK - 772     37
# UK - 776     36
# UK - 996     36
# AI - 515     36
# AI - 402     35
# UK - 958     35
# UK - 944     35
# AI - 770     34
# UK - 816     34
# AI - 538     33
# AI - 619     33
# UK - 812     32
# AI - 676     32
# UK - 994     32
# UK - 802     32
# AI - 637     30
# UK - 720     30
# AI - 651     30
# AI - 539     30
# AI - 9893    30
# UK - 863     29
# AI - 9890    28
# AI - 638     28
# UK - 870     28
# AI - 698     28
# UK - 810     28
# UK - 928     28
# UK - 890     27
# UK - 830     26
# AI - 532     26
# AI - 9547    26
# UK - 655     25
# UK - 708     24
# UK - 778     24
# AI - 766     24
# AI - 665     24
# AI - 611     24
# AI - 805     24
# AI - 624     23
# AI - 625     23
# AI - 773     23
# AI - 887     22
# AI - 636     22
# UK - 841     22
# UK - 865     22
# UK - 842     21
# UK - 822     21
# AI - 469     21
# AI - 862     21
# 6E - 6262    21
# AI - 441     20
# UK - 771     20
# AI - 852     20
# AI - 526     20
# AI - 868     20
# AI - 672     20
# AI - 765     20
# UK - 860     19
# AI - 631     19
# AI - 9875    19
# 6E - 6288    18
# UK - 826     18
# 6E - 816     17
# AI - 9876    17
# UK - 775     17
# 6E - 5318    17
# 6E - 5209    16
# UK - 836     16
# G8 - 334     16
# UK - 637     16
# 6E - 5006    15
# AI - 675     15
# AI - 747     15
# 6E - 2065    15
# AI - 803     15
# G8 - 327     15
# 6E - 5394    15
# 6E - 2138    15
# 6E - 5359    15
# AI - 502     14
# 6E - 5312    14
# UK - 824     14
# AI - 423     14
# 6E - 599     14
# 6E - 5324    14
# AI - 683     13
# AI - 9887    13
# 6E - 2372    13
# G8 - 302     13
# AI - 743     13
# G8 - 385     13
# AI - 523     13
# UK - 985     13
# AI - 649     13
# SG - 8412    13
# G8 - 381     13
# UK - 832     13
# SG - 8646    13
# AI - 544     13
# 6E - 5002    13
# UK - 834     13
# 6E - 168     12
# AI - 504     12
# 6E - 5207    12
# UK - 955     12
# 6E - 6137    12
# AI - 9885    12
# 6E - 494     12
# AI - 506     12
# UK - 951     12
# G8 - 720     12
# 6E - 6425    12
# AI - 9755    12
# AI - 738     12
# G8 - 459     12
# G8 - 227     12
# 6E - 6513    12
# 6E - 2005    12
# 6E - 6111    12
# 6E - 886     12
# G8 - 330     12
# AI - 774     12
# 6E - 354     12
# 6E - 5395    12
# 6E - 139     12
# AI - 764     12
# 6E - 6738    12
# AI - 627     11
# 6E - 2024    11
# 6E - 6737    11
# 6E - 541     11
# 6E - 672     11
# 6E - 2015    11
# AI - 739     11
# SG - 8152    11
# AI - 807     11
# AI - 877     11
# UK - 941     11
# 6E - 6324    11
# UK - 993     11
# 6E - 744     11
# 6E - 5124    11
# 6E - 495     11
# 6E - 2364    10
# 6E - 199     10
# AI - 885     10
# 6E - 137     10
# 6E - 6205    10
# 6E - 5004    10
# 6E - 827     10
# 6E - 5001    10
# 6E - 413     10
# 6E - 5307    10
# AI - 9501    10
# 6E - 204     10
# AI - 883     10
# AI - 401     10
# 6E - 893     10
# 6E - 394     10
# AI - 9657    10
# 6E - 6463    10
# 6E - 345     10
# UK - 612     10
# UK - 946     10
# AI - 435     10
# 6E - 132     10
# UK - 705     10
# G8 - 537     10
# G8 - 2610     9
# G8 - 392      9
# 6E - 455      9
# 6E - 6576     9
# AI - 850      9
# AI - 9505     9
# 6E - 5079     9
# 6E - 269      9
# 6E - 702      9
# AI - 729      9
# 6E - 2182     9
# AI - 878      9
# AI - 839      9
# UK - 673      9
# G8 - 336      9
# 6E - 796      9
# 6E - 249      9
# 6E - 6151     9
# SG - 8194     9
# 6E - 5358     9
# AI - 542      9
# G8 - 341      9
# 6E - 5039     9
# 6E - 6219     8
# 6E - 822      8
# G8 - 176      8
# 6E - 2337     8
# UK - 829      8
# G8 - 714      8
# AI - 560      8
# AI - 540      8
# 6E - 136      8
# UK - 966      8
# 6E - 247      8
# UK - 747      8
# AI - 9745     8
# UK - 927      8
# SG - 8158     8
# AI - 669      8
# 6E - 6021     8
# G8 - 323      8
# 6E - 5365     8
# AI - 886      8
# 6E - 5328     8
# 6E - 2339     8
# 6E - 179      7
# 6E - 6684     7
# UK - 926      7
# 6E - 2405     7
# SG - 8169     7
# UK - 819      7
# 6E - 6749     7
# SG - 8702     7
# UK - 972      7
# AI - 699      7
# UK - 611      7
# AI - 645      7
# 6E - 124      7
# 6E - 514      7
# 6E - 2687     7
# 6E - 6014     7
# AI - 416      7
# SG - 8130     7
# 6E - 757      7
# AI - 664      7
# 6E - 605      7
# 6E - 996      7
# 6E - 563      7
# G8 - 364      7
# AI - 429      7
# 6E - 349      7
# 6E - 591      7
# AI - 826      7
# AI - 663      7
# UK - 788      7
# 6E - 6238     7
# G8 - 320      7
# 6E - 423      7
# AI - 453      7
# SG - 8937     7
# AI - 822      6
# 6E - 2091     6
# 6E - 5175     6
# 6E - 841      6
# 6E - 6172     6
# I5 - 1452     6
# SG - 241      6
# UK - 823      6
# 6E - 304      6
# 6E - 224      6
# 6E - 728      6
# G8 - 424      6
# UK - 642      6
# AI - 670      6
# 6E - 503      6
# AI - 9881     6
# AI - 9741     6
# AI - 537      6
# UK - 998      6
# 6E - 5399     6
# UK - 833      6
# 6E - 5366     6
# 6E - 5072     6
# 6E - 6567     6
# SG - 467      6
# AI - 473      6
# 6E - 391      6
# UK - 651      6
# 6E - 5383     6
# 6E - 6097     6
# SG - 731      5
# G8 - 717      5
# SG - 388      5
# AI - 671      5
# AI - 1627     5
# 6E - 2061     5
# UK - 718      5
# UK - 839      5
# 6E - 453      5
# 6E - 6359     5
# I5 - 1426     5
# AI - 685      5
# 6E - 5164     5
# G8 - 317      5
# 6E - 539      5
# 6E - 383      5
# AI - 483      5
# 6E - 6326     5
# G8 - 191      5
# AI - 763      5
# AI - 406      5
# 6E - 5434     5
# 6E - 152      5
# G8 - 803      5
# SG - 481      5
# 6E - 2513     5
# UK - 825      5
# G8 - 101      5
# 6E - 929      5
# SG - 480      5
# 6E - 751      5
# UK - 782      5
# 6E - 531      5
# 6E - 293      5
# SG - 2974     5
# 6E - 5217     5
# AI - 889      5
# AI - 474      5
# 6E - 711      5
# AI - 684      5
# 6E - 5347     4
# SG - 2976     4
# 6E - 712      4
# 6E - 6222     4
# I5 - 1576     4
# G8 - 332      4
# 6E - 2062     4
# AI - 891      4
# 6E - 903      4
# 6E - 321      4
# AI - 439      4
# SG - 3756     4
# 6E - 6006     4
# G8 - 461      4
# 6E - 2338     4
# 6E - 6358     4
# 6E - 849      4
# 6E - 6067     4
# AI - 9810     4
# AI - 9886     4
# G8 - 275      4
# AI - 9548     4
# AI - 812      4
# 6E - 183      4
# G8 - 348      4
# G8 - 203      4
# AI - 9882     4
# G8 - 502      4
# UK - 871      4
# 6E - 995      1
# Name: flight_id, dtype: int64

# %%
df['stops'].value_counts()
# Out:
# 1 stop at Delhi                      1858
# 1 stop at Mumbai                      670
# Non Stop                              557
# 2 Stops (BOM, DEL)                    321
# 1 stop at Hyderabad                   258
# 2 Stops (DEL, BOM)                    255
# 1 stop at Bengaluru                   224
# 2 Stops (HYD, DEL)                    186
# 1 stop at Kolkata                     171
# 2 Stops (BLR, DEL)                    166
# 1 stop at Chennai                     109
# 2 Stops (CCU, DEL)                     61
# 2 Stops (GOI, DEL)                     51
# 2 Stops (MAA, DEL)                     50
# 2 Stops (IXC, DEL)                     46
# 1 stop at Goa                          46
# 3 Stops (BBI, STV, DEL)                42
# 2 Stops (IXU, DEL)                     37
# 1 stop at Ahmedabad                    36
# 2 Stops (DEL, BHO)                     35
# 2 Stops (DEL, SXR)                     35
# 2 Stops (IDR, DEL)                     33
# 2 Stops (DEL, MAA)                     33
# 2 Stops (JAI, DEL)                     31
# 2 Stops (JDH, DEL)                     30
# 2 Stops (DEL, LKO)                     28
# 2 Stops (MAA, BOM)                     25
# 1 stop at Pune                         25
# 2 Stops (AMD, DEL)                     25
# 1 stop at Srinagar                     25
# 3 Stops (DEL, BOM, IXE)                25
# 2 Stops (GAU, DEL)                     24
# 2 Stops (BLR, BOM)                     24
# 2 Stops (IXC, BOM)                     23
# 3 Stops (DEL, BOM, RPR)                21
# 2 Stops (DEL, HYD)                     21
# 1 stop at Indore                       21
# 1 stop at Patna                        20
# 2 Stops (HYD, BOM)                     20
# 2 Stops (BBI, DEL)                     20
# 2 Stops (DEL, GOP)                     19
# 2 Stops (IXJ, DEL)                     18
# 2 Stops (GOI, BOM)                     18
# 2 Stops (RPR, DEL)                     18
# 2 Stops (DEL, NAG)                     17
# 2 Stops (BHO, DEL)                     17
# 2 Stops (DEL, BLR)                     17
# 2 Stops (DEL, RPR)                     16
# 1 stop at Raipur                       16
# 2 Stops (CCU, BOM)                     16
# 2 Stops (IXU, BOM)                     16
# 3 Stops (DEL, IXU, BOM)                15
# 2 Stops (IDR, BOM)                     15
# 2 Stops (IXA, DEL)                     15
# 4 Stops (DEL, NAG, RPR, JRG)           14
# 1 stop at Jaipur                       14
# 3 Stops (DEL, PNQ, ISK)                14
# 2 Stops (TRV, BOM)                     14
# 3 Stops (KLH, BLR, DEL)                14
# 1 stop at Lucknow                      14
# 2 Stops (LKO, DEL)                     14
# 3 Stops (KLH, HYD, DEL)                13
# 1 stop at Bhubaneshwar                 13
# 2 Stops (AMD, BOM)                     13
# 3 Stops (DEL, AMD, ISK)                12
# 2 Stops (DEL, DIB)                     12
# 2 Stops (BLR, HYD)                     11
# 2 Stops (NAG, DEL)                     11
# 3 Stops (BOM, IDR, DEL)                11
# 2 Stops (ATQ, DEL)                     10
# 3 Stops (DEL, BBI, JRG)                10
# 3 Stops (CCU, BLR, DEL)                10
# 2 Stops (BLR, MYQ)                     10
# 3 Stops (DEL, HYD, JGB)                10
# 3 Stops (ISK, AMD, DEL)                10
# 2 Stops (DEL, IXL)                     10
# 2 Stops (VNS, BOM)                     10
# 2 Stops (VGA, DEL)                      9
# 2 Stops (BLR, CCU)                      9
# 1 stop at Jammu                         9
# 1 stop at Guwahati                      9
# 3 Stops (BLR, TRV, BOM)                 9
# 2 Stops (BOM, RPR)                      9
# 1 stop at Chandigarh                    9
# 1 stop at Varanasi                      8
# 2 Stops (BOM, IXE)                      8
# 3 Stops (BOM, IXU, DEL)                 8
# 2 Stops (STV, DEL)                      8
# 1 stop at Nagpur                        8
# 3 Stops (BLR, DEL, NAG)                 8
# 4 Stops (DEL, IXU, BOM, IXE)            8
# 2 Stops (BOM, MAA)                      8
# 3 Stops (DEL, IDR, BOM)                 8
# 3 Stops (HYD, DEL, BHO)                 8
# 2 Stops (BHO, BOM)                      7
# 2 Stops (BOM, BBI)                      7
# 1 stop at Bhopal                        7
# 2 Stops (BOM, PAT)                      7
# 3 Stops (DEL, NAG, RPR)                 7
# 3 Stops (JGB, RPR, DEL)                 7
# 3 Stops (DEL, IXC, BOM)                 7
# 2 Stops (HYD, CCU)                      7
# 3 Stops (PAT, CCU, DEL)                 7
# 2 Stops (DEL, IXJ)                      7
# 2 Stops (BBI, BOM)                      6
# 3 Stops (BOM, DEL, NAG)                 6
# 2 Stops (PAT, DEL)                      6
# 3 Stops (LKO, GOP, DEL)                 6
# 3 Stops (DEL, BLR, MYQ)                 6
# 4 Stops (CCU, BBI, STV, DEL)            6
# 4 Stops (DEL, IXU, BOM, RPR)            6
# 2 Stops (HYD, BLR)                      5
# 1 stop at Mysore                        5
# 3 Stops (BOM, DEL, RPR)                 5
# 1 stop at Vijayawada                    5
# 4 Stops (DEL, IDR, BOM, IXE)            5
# 2 Stops (DEL, VGA)                      5
# 2 Stops (BOM, CCU)                      5
# 3 Stops (STV, BBI, CCU)                 5
# 1 stop at Jodhpur                       5
# 1 stop at Mangalore                     5
# 2 Stops (HYD, JGB)                      5
# 2 Stops (PAT, CCU)                      4
# 3 Stops (BLR, DEL, SXR)                 4
# 2 Stops (LKO, BOM)                      4
# 2 Stops (HYD, MYQ)                      4
# 3 Stops (TRV, BOM, DEL)                 4
# 2 Stops (CCU, IXZ)                      4
# 1 stop at Surat                         4
# 3 Stops (DEL, RPR, JGB)                 4
# 3 Stops (DEL, BOM, PAT)                 4
# 1 stop at Udaipur                       4
# 3 Stops (MYQ, COK, DEL)                 4
# 1 stop at Bagdogra                      4
# 3 Stops (IDR, DEL, MAA)                 4
# 2 Stops (ATQ, BOM)                      4
# 3 Stops (IDR, DEL, HYD)                 4
# 3 Stops (IXC, BOM, BBI)                 4
# 2 Stops (BOM, BLR)                      4
# 2 Stops (CCU, JRG)                      4
# 3 Stops (RPR, JRG, CCU)                 4
# 1 stop at Agartala                      4
# 2 Stops (IXZ, DEL)                      3
# 2 Stops (RPR, JGB)                      3
# 3 Stops (DEL, RPR, JRG)                 3
# 2 Stops (GOP, DEL)                      3
# 2 Stops (BLR, PAT)                      3
# 3 Stops (IXU, DEL, MAA)                 3
# 2 Stops (DEL, VNS)                      3
# 3 Stops (GOI, DEL, NAG)                 3
# 2 Stops (DEL, BBI)                      3
# 2 Stops (AMD, ISK)                      3
# 3 Stops (MYQ, GOI, DEL)                 3
# 4 Stops (IDR, DEL, BLR, MYQ)            3
# 1 stop at Ranchi                        3
# 3 Stops (GOI, BOM, IXE)                 3
# 2 Stops (KLH, HYD)                      3
# 2 Stops (COK, MYQ)                      3
# 3 Stops (BOM, DEL, LKO)                 3
# 2 Stops (BLR, KLH)                      3
# 1 stop at Gwalior                       3
# 3 Stops (NAG, RPR, DEL)                 3
# 1 stop at Madurai                       3
# 2 Stops (RPR, IDR)                      3
# 3 Stops (JGB, HYD, DEL)                 3
# 2 Stops (STV, BBI)                      3
# 2 Stops (RPR, JRG)                      3
# 2 Stops (VNS, DEL)                      3
# 3 Stops (MYQ, HYD, DEL)                 3
# 4 Stops (DEL, IDR, BOM, RPR)            3
# 1 stop at Jharsuguda                    3
# 3 Stops (BOM, AMD, ISK)                 3
# 2 Stops (BBI, HYD)                      3
# 2 Stops (IDR, CCU)                      3
# 3 Stops (NAG, DEL, BOM)                 3
# 3 Stops (RPR, VTZ, DEL)                 3
# 4 Stops (JRG, BBI, STV, DEL)            3
# 2 Stops (GOI, MYQ)                      3
# 3 Stops (BBI, DEL, MAA)                 2
# 2 Stops (CCU, AJL)                      2
# 2 Stops (SXR, DEL)                      2
# 2 Stops (COK, BOM)                      2
# 2 Stops (DEL, PAT)                      2
# 1 stop at Tirupati                      2
# 4 Stops (IDR, DEL, HYD, JGB)            2
# 4 Stops (ISK, AMD, DEL, NAG)            2
# 3 Stops (BOM, IXC, DEL)                 2
# 1 stop at Imphal                        2
# 3 Stops (ATQ, DEL, IXJ)                 2
# 3 Stops (IDR, BOM, CCU)                 2
# 1 stop at Coimbatore                    2
# 3 Stops (BOM, DEL, MAA)                 2
# 3 Stops (MYQ, COK, BOM)                 2
# 1 stop at Kannur                        2
# 3 Stops (GOI, DEL, MAA)                 2
# 3 Stops (JAI, DEL, NAG)                 2
# 2 Stops (CCU, IDR)                      2
# 2 Stops (KLH, BLR)                      2
# 1 stop at Kochi                         2
# 4 Stops (BBI, STV, DEL, BHO)            2
# 2 Stops (VTZ, IXZ)                      2
# 3 Stops (HYD, DEL, SXR)                 2
# 3 Stops (BOM, DEL, GOP)                 2
# 1 stop at Amritsar                      2
# 4 Stops (KLH, BLR, DEL, NAG)            2
# 3 Stops (BLR, PAT, CCU)                 2
# 3 Stops (CCU, DMU, SHL)                 2
# 2 Stops (IDR, RPR)                      2
# 3 Stops (BOM, CCU, DEL)                 2
# 2 Stops (RPR, VTZ)                      2
# 4 Stops (BBI, STV, DEL, MAA)            2
# 2 Stops (AMD, IXC)                      2
# 3 Stops (HYD, DEL, GOP)                 2
# 2 Stops (PNQ, ISK)                      2
# 3 Stops (IDR, DEL, BLR)                 2
# 4 Stops (DEL, IXU, BOM, PAT)            2
# 1 stop at Vishakhapatnam                2
# 4 Stops (CCU, BLR, DEL, GOP)            2
# 2 Stops (BBI, JRG)                      2
# 3 Stops (IXU, DEL, HYD)                 2
# 1 stop at Gorakhpur                     2
# 1 stop at Jabalpur                      2
# 2 Stops (IXL, IXJ)                      2
# 2 Stops (BLR, PNQ)                      2
# 3 Stops (IXU, DEL, SXR)                 2
# 3 Stops (BBI, DEL, NAG)                 1
# 2 Stops (VTZ, BOM)                      1
# 3 Stops (ATQ, BOM, RPR)                 1
# 5 Stops (JRG, BBI, STV, DEL, NAG)       1
# 3 Stops (RPR, DEL, MAA)                 1
# 3 Stops (PAT, CCU, JRG)                 1
# 3 Stops (DEL, BLR, HYD)                 1
# 4 Stops (BOM, IXU, DEL, MAA)            1
# 3 Stops (MAA, DEL, BHO)                 1
# 3 Stops (BOM, IXE, CJB)                 1
# 2 Stops (MAA, IXZ)                      1
# 3 Stops (MYQ, BLR, BOM)                 1
# 3 Stops (IXU, DEL, BHO)                 1
# 4 Stops (TRV, BOM, IDR, DEL)            1
# 3 Stops (GOI, IDR, RPR)                 1
# 2 Stops (JRG, RPR)                      1
# 2 Stops (AMD, CCU)                      1
# 3 Stops (IDR, DEL, RPR)                 1
# 3 Stops (ATQ, BOM, IXE)                 1
# 1 stop at Baroda                        1
# 2 Stops (JGB, RPR)                      1
# 1 stop at Leh                           1
# 3 Stops (CCU, DEL, SXR)                 1
# 4 Stops (BBI, STV, DEL, GOP)            1
# 3 Stops (IDR, DEL, NAG)                 1
# 3 Stops (KLH, BLR, MYQ)                 1
# 3 Stops (JAI, DEL, BHO)                 1
# 3 Stops (TRV, BOM, IXE)                 1
# 3 Stops (IXC, DEL, LKO)                 1
# 3 Stops (IXU, DEL, IXJ)                 1
# 3 Stops (BLR, DEL, MAA)                 1
# 4 Stops (JGB, RPR, DEL, MAA)            1
# 2 Stops (CCU, AMD)                      1
# 2 Stops (DMU, SHL)                      1
# 3 Stops (CCU, AMD, BOM)                 1
# 3 Stops (GOP, DEL, BOM)                 1
# 3 Stops (GOP, LKO, BOM)                 1
# 3 Stops (PAT, CCU, IMF)                 1
# 3 Stops (IXU, BOM, RPR)                 1
# 3 Stops (HYD, DEL, IXJ)                 1
# 4 Stops (JRG, BBI, DEL, NAG)            1
# 3 Stops (JAI, DEL, MAA)                 1
# 3 Stops (RPR, IDR, GOI)                 1
# 1 stop at Port Blair                    1
# 3 Stops (JDH, DEL, SXR)                 1
# 4 Stops (IDR, DEL, RPR, JGB)            1
# 3 Stops (STV, BBI, BLR)                 1
# 2 Stops (DEL, GAU)                      1
# 3 Stops (AMD, DEL, NAG)                 1
# 2 Stops (PNQ, BBI)                      1
# 2 Stops (UDR, BOM)                      1
# 4 Stops (JGB, RPR, VTZ, BOM)            1
# 2 Stops (CCU, IMF)                      1
# 3 Stops (IXU, DEL, VGA)                 1
# 3 Stops (BBI, HYD, BLR)                 1
# 3 Stops (AMD, BOM, IXE)                 1
# 2 Stops (HYD, MAA)                      1
# 1 stop at Jagdalpur                     1
# 3 Stops (LKO, DEL, MAA)                 1
# 2 Stops (GAU, IMF)                      1
# 2 Stops (VTZ, DEL)                      1
# 3 Stops (CCU, BOM, IXE)                 1
# 5 Stops (IXU, DEL, NAG, RPR, JRG)       1
# 3 Stops (STV, BBI, JRG)                 1
# 3 Stops (IDR, BOM, RPR)                 1
# 3 Stops (AMD, DEL, IXJ)                 1
# 3 Stops (GOI, DEL, SXR)                 1
# 4 Stops (STV, DEL, NAG, RPR)            1
# 3 Stops (IXU, DEL, GOP)                 1
# 3 Stops (AMD, DEL, MAA)                 1
# 2 Stops (NAG, BOM)                      1
# 4 Stops (LKO, GOP, DEL, NAG)            1
# 3 Stops (IXU, DEL, NAG)                 1
# 3 Stops (MYQ, HYD, BOM)                 1
# 4 Stops (BBI, STV, DEL, BOM)            1
# 3 Stops (PAT, CCU, AJL)                 1
# 2 Stops (IXE, CJB)                      1
# 3 Stops (GOI, BOM, RPR)                 1
# 2 Stops (RAJ, DEL)                      1
# 2 Stops (GOI, HYD)                      1
# 3 Stops (BHO, BOM, RPR)                 1
# 4 Stops (IXU, DEL, BLR, MYQ)            1
# 4 Stops (BLR, TRV, BOM, RPR)            1
# 3 Stops (HYD, KLH, BLR)                 1
# 3 Stops (IDR, BOM, PAT)                 1
# 1 stop at Silchar                       1
# 3 Stops (IXL, IXJ, SXR)                 1
# 3 Stops (CCU, DEL, GOP)                 1
# 3 Stops (CCU, DEL, NAG)                 1
# 4 Stops (NAG, DEL, IXU, BOM)            1
# 3 Stops (TRV, BOM, RPR)                 1
# 3 Stops (HYD, BOM, IXE)                 1
# 3 Stops (JRG, BBI, DEL)                 1
# 2 Stops (GAU, IXA)                      1
# 2 Stops (CCU, BLR)                      1
# 3 Stops (LKO, BOM, IXE)                 1
# 3 Stops (IDR, BOM, IXE)                 1
# 3 Stops (IXU, DEL, BLR)                 1
# 3 Stops (IDR, DEL, GOP)                 1
# 3 Stops (TRV, BOM, PAT)                 1
# 3 Stops (MYQ, GOI, BOM)                 1
# 4 Stops (BBI, STV, DEL, NAG)            1
# 2 Stops (DEL, CCU)                      1
# 2 Stops (RPR, NAG)                      1
# 2 Stops (IXJ, SXR)                      1
# 2 Stops (BBI, CCU)                      1
# 2 Stops (BBI, BLR)                      1
# 3 Stops (JDH, DEL, NAG)                 1
# 2 Stops (MYQ, BLR)                      1
# 5 Stops (BBI, STV, DEL, NAG, RPR)       1
# 4 Stops (MYQ, BLR, TRV, BOM)            1
# 2 Stops (SXR, IXC)                      1
# 2 Stops (JDH, BOM)                      1
# 3 Stops (JGB, RPR, JRG)                 1
# 3 Stops (BHO, BOM, IXE)                 1
# 1 stop at Kozhikode                     1
# 3 Stops (AMD, BOM, RPR)                 1
# 3 Stops (PAT, DEL, MAA)                 1
# 4 Stops (IXU, DEL, HYD, JGB)            1
# 3 Stops (MAA, RPR, IDR)                 1
# 4 Stops (BOM, IXU, DEL, NAG)            1
# 3 Stops (JGB, HYD, BOM)                 1
# 1 stop at Kolhapur                      1
# 3 Stops (STV, DEL, NAG)                 1
# 4 Stops (BOM, IDR, DEL, GOP)            1
# 3 Stops (IXU, BOM, IXE)                 1
# 2 Stops (BOM, BHO)                      1
# 3 Stops (BHO, DEL, IXJ)                 1
# 3 Stops (IXU, BOM, PAT)                 1
# 1 stop at Rajkot                        1
# 3 Stops (JRG, RPR, DEL)                 1
# 3 Stops (BLR, DEL, IXJ)                 1
# 3 Stops (BOM, BLR, HYD)                 1
# 3 Stops (VGA, DEL, BHO)                 1
# 1 stop at Prayagraj                     1
# 1 stop at Aurangabad                    1
# Name: stops, dtype: int64

# %%
# Chaning Column 
df.head()
# Out:
#   flight_name flight_id start_time end_time travel_time                stops  \
# 0    Go First  G8 - 336      14:20    16:35      2h 15m             Non Stop
# 1    Go First  G8 - 392      12:45    15:00      2h 15m             Non Stop
# 2    Go First  G8 - 323      18:05    20:25      2h 20m             Non Stop
# 3    Go First  G8 - 717      16:45    21:25      4h 40m  1 stop at Ahmedabad
# 4    Go First  G8 - 167      15:00    21:55      6h 55m     1 stop at Ranchi
#
#     fare     source destination
# 0  5,954  DEL-Delhi  BOM-Mumbai
# 1  5,954  DEL-Delhi  BOM-Mumbai
# 2  5,954  DEL-Delhi  BOM-Mumbai
# 3  5,954  DEL-Delhi  BOM-Mumbai
# 4  5,954  DEL-Delhi  BOM-Mumbai

# %%
df['source'].value_counts()
# Out:
# BOM-Mumbai                1578
# DEL-Delhi                 1052
# BLR-Bengaluru              989
# HYD-Hyderabad              756
# CU-Kolkata                 719
# MAA-Chennai                557
# AMD-Ahmedabad              300
# GOI-Goa                    183
# PNQ-Pune                   128
# COK-Kochi                  106
# SXR-Srinagar                96
# BBI-Bhubaneshwar            83
# PAT-Patna                   74
# GAU-Guwahati                59
# LKO-Lucknow                 54
# JAI-Jaipur                  33
# IXB-Bagdogra                31
# RPR-Raipur                  29
# IXC-Chandigarh              21
# NAG-Nagpur                  19
# VNS-Varanasi                17
# VTZ-Vishakhapatnam          14
# IXR-Ranchi                   9
# IDR-Indore                   7
# IXJ-Jammu                    3
# CJB-Coimbatore               2
# ATQ-Amritsar                 2
# TRV-Thiruvananthapuram       1
# CCJ-Kozhikode                1
# Name: source, dtype: int64

# %%
df['destination'].value_counts()
# Out:
# IXC-Chandigarh            417
# AMD-Ahmedabad             393
# MAA-Chennai               373
# GOI-Goa                   373
# PNQ-Pune                  372
# LKO-Lucknow               368
# COK-Kochi                 297
# VNS-Varanasi              296
# CU-Kolkata                295
# IDR-Indore                290
# JAI-Jaipur                276
# BBI-Bhubaneshwar          266
# GAU-Guwahati              259
# RPR-Raipur                253
# CJB-Coimbatore            241
# VTZ-Vishakhapatnam        241
# HYD-Hyderabad             223
# ATQ-Amritsar              221
# SXR-Srinagar              211
# BLR-Bengaluru             190
# PAT-Patna                 187
# IXR-Ranchi                157
# TRV-Thiruvananthapuram    143
# IXJ-Jammu                 136
# NAG-Nagpur                124
# DED-Dehradun               97
# IXB-Bagdogra               89
# BOM-Mumbai                 83
# CCJ-Kozhikode              52
# Name: destination, dtype: int64

# %%
# Chanign start_time	end_time	travel_time	stops	fare

# %%
# fare
df['fare'] = df['fare'].str.replace(',', '')
df['fare'] = df['fare'].astype('int')

# %%
df.head()
# Out:
#   flight_name flight_id start_time end_time travel_time                stops  \
# 0    Go First  G8 - 336      14:20    16:35      2h 15m             Non Stop
# 1    Go First  G8 - 392      12:45    15:00      2h 15m             Non Stop
# 2    Go First  G8 - 323      18:05    20:25      2h 20m             Non Stop
# 3    Go First  G8 - 717      16:45    21:25      4h 40m  1 stop at Ahmedabad
# 4    Go First  G8 - 167      15:00    21:55      6h 55m     1 stop at Ranchi
#
#    fare     source destination
# 0  5954  DEL-Delhi  BOM-Mumbai
# 1  5954  DEL-Delhi  BOM-Mumbai
# 2  5954  DEL-Delhi  BOM-Mumbai
# 3  5954  DEL-Delhi  BOM-Mumbai
# 4  5954  DEL-Delhi  BOM-Mumbai

# %%
# change stops
df['stops'] = df['stops'].str.lower().apply(lambda X: X.split('stop')[0])
df['stops'] = df['stops'].str.replace('non','0')
df['stops'] = df['stops'].astype('int')

# %%
df.head()
# Out:
#   flight_name flight_id start_time end_time travel_time  stops  fare  \
# 0    Go First  G8 - 336      14:20    16:35      2h 15m      0  5954
# 1    Go First  G8 - 392      12:45    15:00      2h 15m      0  5954
# 2    Go First  G8 - 323      18:05    20:25      2h 20m      0  5954
# 3    Go First  G8 - 717      16:45    21:25      4h 40m      1  5954
# 4    Go First  G8 - 167      15:00    21:55      6h 55m      1  5954
#
#       source destination
# 0  DEL-Delhi  BOM-Mumbai
# 1  DEL-Delhi  BOM-Mumbai
# 2  DEL-Delhi  BOM-Mumbai
# 3  DEL-Delhi  BOM-Mumbai
# 4  DEL-Delhi  BOM-Mumbai

# %%
def change_time(one_time):
    
    hour = 0 
    minute = 0
    
    one_time_change = one_time
    if 'h' in one_time_change:
        hour = one_time_change.split('h')[0]
        one_time_change = one_time.split('h')[1]
        
    if 'm' in one_time_change:
        minute = one_time_change.split('m')[0]
        
    return (
        int(hour) * 60 
            + 
        int(minute)
    )

# %%
df['travel_time'] = df['travel_time'].apply(change_time)

# %%
df.head()
# Out:
#   flight_name flight_id start_time end_time  travel_time  stops  fare  \
# 0    Go First  G8 - 336      14:20    16:35          135      0  5954
# 1    Go First  G8 - 392      12:45    15:00          135      0  5954
# 2    Go First  G8 - 323      18:05    20:25          140      0  5954
# 3    Go First  G8 - 717      16:45    21:25          280      1  5954
# 4    Go First  G8 - 167      15:00    21:55          415      1  5954
#
#       source destination
# 0  DEL-Delhi  BOM-Mumbai
# 1  DEL-Delhi  BOM-Mumbai
# 2  DEL-Delhi  BOM-Mumbai
# 3  DEL-Delhi  BOM-Mumbai
# 4  DEL-Delhi  BOM-Mumbai

# %%
# Chanign start_Time 
df[['start_time_hh','start_time_mm']] = df['start_time'].str.split(':',expand=True)

# %%
# Chanign end_time 
df[['end_time_hh','end_time_mm']] = df['end_time'].str.split(':',expand=True)

# %%
# droping orignal column
df.drop(['start_time','end_time',],axis=1,inplace=True)

# %%
df.head()
# Out:
#   flight_name flight_id  travel_time  stops  fare     source destination  \
# 0    Go First  G8 - 336          135      0  5954  DEL-Delhi  BOM-Mumbai
# 1    Go First  G8 - 392          135      0  5954  DEL-Delhi  BOM-Mumbai
# 2    Go First  G8 - 323          140      0  5954  DEL-Delhi  BOM-Mumbai
# 3    Go First  G8 - 717          280      1  5954  DEL-Delhi  BOM-Mumbai
# 4    Go First  G8 - 167          415      1  5954  DEL-Delhi  BOM-Mumbai
#
#   start_time_hh start_time_mm end_time_hh end_time_mm
# 0            14            20          16          35
# 1            12            45          15          00
# 2            18            05          20          25
# 3            16            45          21          25
# 4            15            00          21          55

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.dtypes
# Out:
# flight_name      object
# flight_id        object
# travel_time       int64
# stops             int64
# fare              int64
# source           object
# destination      object
# start_time_hh    object
# start_time_mm    object
# end_time_hh      object
# end_time_mm      object
# dtype: object

# %%
df
# Out:
#      flight_name  flight_id  travel_time  stops   fare          source  \
# 0       Go First   G8 - 336          135      0   5954       DEL-Delhi
# 1       Go First   G8 - 392          135      0   5954       DEL-Delhi
# 2       Go First   G8 - 323          140      0   5954       DEL-Delhi
# 3       Go First   G8 - 717          280      1   5954       DEL-Delhi
# 4       Go First   G8 - 167          415      1   5954       DEL-Delhi
# ...          ...        ...          ...    ...    ...             ...
# 7029      IndiGo   6E - 137          680      2  12092       IXJ-Jammu
# 7030      IndiGo   6E - 124          405      1  14454       IXJ-Jammu
# 7031      IndiGo  6E - 6738          605      1  14454       IXJ-Jammu
# 7032      IndiGo  6E - 6152          660      1  10782  CJB-Coimbatore
# 7033      IndiGo  6E - 2189          435      1  12357  CJB-Coimbatore
#
#          destination start_time_hh start_time_mm end_time_hh end_time_mm
# 0         BOM-Mumbai            14            20          16          35
# 1         BOM-Mumbai            12            45          15          00
# 2         BOM-Mumbai            18            05          20          25
# 3         BOM-Mumbai            16            45          21          25
# 4         BOM-Mumbai            15            00          21          55
# ...              ...           ...           ...         ...         ...
# 7029  CJB-Coimbatore            11            55          23          15
# 7030  CJB-Coimbatore            16            30          23          15
# 7031  CJB-Coimbatore            13            10          23          15
# 7032    DED-Dehradun            06            05          17          05
# 7033    DED-Dehradun            23            55          07          10
#
# [6923 rows x 11 columns]

# %%
# Univaite analysis 
plt.figure(figsize=(15,200))
for i, column_data in enumerate(df.dtypes.items()):
    plt.subplot(25,1,i+1)
    plt.subplots_adjust(hspace=1)
    column, dtype = column_data
    
    if dtype == 'object':
        plt.xticks(rotation=90)
        sns.countplot(x=column,data=df)
        
    else:
        plt.xticks(rotation=90)
        sns.histplot(df[column], kde=True)

# %%
#Bivariate analysis 
plt.figure(figsize=[15,200])
j = 0 
for column, dtype in df.drop('fare',axis=1).dtypes.items():
    if dtype == 'object':
        plt.subplot(30,1,j+1)  
        plt.xticks(rotation=90)
        plt.subplots_adjust(hspace=1)
        plt.title(column + " vs fare", fontsize = 20)
        sns.barplot(x = df[column],y = df['fare'],)
        j += 1

# %%
# Label ENcoding

# %%
obj_columns = df.select_dtypes('object').columns
obj_columns
# Out:
# Index(['flight_name', 'flight_id', 'source', 'destination', 'start_time_hh',
#        'start_time_mm', 'end_time_hh', 'end_time_mm'],
#       dtype='object')

# %%
df[obj_columns] = df[obj_columns].apply(LabelEncoder().fit_transform)

# %%
df
# Out:
#       flight_name  flight_id  travel_time  stops   fare  source  destination  \
# 0               2        718          135      0   5954       9            4
# 1               2        734          135      0   5954       9            4
# 2               2        712          140      0   5954       9            4
# 3               2        753          280      1   5954       9            4
# 4               2        677          415      1   5954       9            4
# ...           ...        ...          ...    ...    ...     ...          ...
# 7029            3         12          680      2  12092      16            6
# 7030            3          6          405      1  14454      16            6
# 7031            3        372          605      1  14454      16            6
# 7032            3        295          660      1  10782       6            9
# 7033            3         66          435      1  12357       6            9
#
#       start_time_hh  start_time_mm  end_time_hh  end_time_mm
# 0                10              4           15            7
# 1                 8              9           14            0
# 2                14              1           19            5
# 3                12              9           20            5
# 4                11              0           20           11
# ...             ...            ...          ...          ...
# 7029              7             11           22            3
# 7030             12              6           22            3
# 7031              9              2           22            3
# 7032              2              1           16            1
# 7033             19             11            6            2
#
# [6923 rows x 11 columns]

# %%
df.boxplot(figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
X = df.drop('fare', axis=1)
y = df['fare']

# %%
X_transformed = MinMaxScaler().fit_transform(X)
X = pd.DataFrame(X_transformed, columns=X.columns)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=True, shuffle=True, test_size=.33)

# %%
models = [
    LinearRegression(),
    RandomForestRegressor(),
    DecisionTreeRegressor(),
    KNeighborsRegressor(),
    GradientBoostingRegressor(),
    Ridge(),
    SVR(),
]

# %%
for model in models:
    print('modal ', model)
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    r2_s = r2_score(y_test,y_pred)
    print('R2 score: ', r2_s)
    print('Mean Absoulte Error: ', mean_absolute_error(y_test,y_pred))
    print('Mean Sqaure Error: ', mean_squared_error(y_test,y_pred))
    print('Root Mean Sqaure: ', r2_score(y_test, y_pred))
    score = cross_val_score(model, X, y, cv=10)
    mean_score = score.mean()
    print('Score: ', score)
    print('corss val score mean: ', mean_score)
    print('diffrence between r2 score - cross val score: ', r2_s - mean_score)
    print('-' * 50)
# Out:
# modal  LinearRegression()
# R2 score:  0.4286728635258734
# Mean Absoulte Error:  2126.3258767008783
# Mean Sqaure Error:  7564551.99078129
# Root Mean Sqaure:  0.4286728635258734
# Score:  [0.44754724 0.46283776 0.34418357 0.36958928 0.42440457 0.36135626
#  0.44940168 0.40780988 0.33934649 0.20323763]
# corss val score mean:  0.3809714369131537
# diffrence between r2 score - cross val score:  0.0477014266127197
# --------------------------------------------------
# modal  RandomForestRegressor()
# R2 score:  0.7464969361281693
# Mean Absoulte Error:  1233.2288308846516
# Mean Sqaure Error:  3356460.7456163717
# Root Mean Sqaure:  0.7464969361281693
# Score:  [0.55804564 0.6578938  0.6924067  0.69825277 0.64863875 0.61203154
#  0.690369   0.70582535 0.34257004 0.26969462]
# corss val score mean:  0.5875728219200923
# diffrence between r2 score - cross val score:  0.15892411420807695
# --------------------------------------------------
# modal  DecisionTreeRegressor()
# R2 score:  0.5098024159101582
# Mean Absoulte Error:  1548.111451495259
# Mean Sqaure Error:  6490371.056917092
# Root Mean Sqaure:  0.5098024159101582
# Score:  [-0.10400389  0.37404138  0.47095891  0.46475228  0.15438802  0.31904286
#   0.29301935  0.31088154 -0.08618736 -0.2778158 ]
# corss val score mean:  0.1919077285312098
# diffrence between r2 score - cross val score:  0.3178946873789484
# --------------------------------------------------
# modal  KNeighborsRegressor()
# R2 score:  0.4956832263171249
# Mean Absoulte Error:  1951.8746608315096
# Mean Sqaure Error:  6677313.592857768
# Root Mean Sqaure:  0.4956832263171249
# Score:  [0.27753047 0.46052668 0.39841263 0.47239889 0.47045628 0.37203198
#  0.48954163 0.419308   0.19530243 0.0524367 ]
# corss val score mean:  0.3607945692492735
# diffrence between r2 score - cross val score:  0.13488865706785141
# --------------------------------------------------
# modal  GradientBoostingRegressor()
# R2 score:  0.6559106590708979
# Mean Absoulte Error:  1593.009358593074
# Mean Sqaure Error:  4555851.705198563
# Root Mean Sqaure:  0.6559106590708979
# Score:  [0.5684912  0.6652369  0.60533635 0.61242974 0.62901653 0.57870846
#  0.65377529 0.65368681 0.39853    0.34272776]
# corss val score mean:  0.5707939047853475
# diffrence between r2 score - cross val score:  0.08511675428555032
# --------------------------------------------------
# modal  Ridge()
# R2 score:  0.42838268993308914
# Mean Absoulte Error:  2127.3969613557924
# Mean Sqaure Error:  7568393.980928153
# Root Mean Sqaure:  0.42838268993308914
# Score:  [0.44774696 0.46243301 0.34408638 0.36929801 0.42455644 0.36238552
#  0.44989361 0.40764183 0.33871746 0.20350707]
# corss val score mean:  0.381026628507874
# diffrence between r2 score - cross val score:  0.047356061425215146
# --------------------------------------------------
# modal  SVR()
# R2 score:  0.03781250103285516
# Mean Absoulte Error:  2854.874569120757
# Mean Sqaure Error:  12739666.814594595
# Root Mean Sqaure:  0.03781250103285516
# Score:  [-0.04450143 -0.07646474  0.02511525 -0.02090893 -0.02177242  0.03769476
#   0.02090925 -0.00066306  0.00802546 -0.01986504]
# corss val score mean:  -0.009243090447776403
# diffrence between r2 score - cross val score:  0.04705559148063156
# --------------------------------------------------

# %%
# Hyper parameter tunning

# %%
param_grid = {
    'max_depth' : range(10,20),
    'criterion' : ['mse'],
    'max_features': ['auto', 'sqrt'],
    'min_samples_leaf': range(2,6),
}
gridSearchCV = GridSearchCV(RandomForestRegressor(),param_grid=param_grid,refit=True,verbose=3)

# %%
gridSearchCV.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [CV 1/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=2; total time=   1.4s
# [CV 2/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=2; total time=   1.4s
# [CV 3/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=2; total time=   1.4s
# [CV 4/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=2; total time=   1.4s
# [CV 5/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=2; total time=   1.4s
# [CV 1/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=3; total time=   1.4s
# [CV 2/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=3; total time=   1.4s
# [CV 3/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=3; total time=   1.3s
# [CV 4/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=3; total time=   1.4s
# [CV 5/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=3; total time=   1.4s
# [CV 1/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=4; total time=   1.3s
# [CV 2/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=4; total time=   1.3s
# [CV 3/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=4; total time=   1.4s
# [CV 4/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=4; total time=   1.7s
# [CV 5/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=4; total time=   2.2s
# [CV 1/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5; total time=   1.7s
# [CV 2/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5; total time=   1.6s
# [CV 3/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 4/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 5/5] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5; total time=   1.3s
# [CV 1/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=2; total time=   0.6s
# [CV 3/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=2; total time=   1.0s
# [CV 4/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 5/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 1/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=3; total time=   0.8s
# [CV 2/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=3; total time=   1.5s
# [CV 5/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=3; total time=   1.0s
# [CV 1/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=4; total time=   0.8s
# [CV 2/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=4; total time=   1.0s
# [CV 3/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=4; total time=   1.0s
# [CV 4/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=4; total time=   1.0s
# [CV 5/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=4; total time=   0.8s
# [CV 1/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 2/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 4/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 5/5] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5; total time=   0.5s
# [CV 1/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=2; total time=   1.5s
# [CV 2/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=2; total time=   1.5s
# [CV 3/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=2; total time=   1.6s
# [CV 4/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=2; total time=   1.5s
# [CV 5/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=2; total time=   1.4s
# [CV 1/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=3; total time=   1.4s
# [CV 2/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=3; total time=   1.4s
# [CV 3/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=3; total time=   1.4s
# [CV 4/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=3; total time=   1.6s
# [CV 5/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=3; total time=   1.6s
# [CV 1/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=4; total time=   1.4s
# [CV 2/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=4; total time=   1.8s
# [CV 3/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=4; total time=   2.3s
# [CV 4/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=4; total time=   2.3s
# [CV 5/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=4; total time=   1.9s
# [CV 1/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=5; total time=   2.8s
# [CV 2/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 3/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=5; total time=   1.8s
# [CV 4/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 5/5] END criterion=mse, max_depth=11, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 1/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=2; total time=   0.6s
# [CV 2/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=2; total time=   0.6s
# [CV 5/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=2; total time=   0.6s
# [CV 1/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=3; total time=   0.6s
# [CV 1/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 2/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 3/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=11, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 1/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=2; total time=   1.5s
# [CV 2/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=2; total time=   1.6s
# [CV 3/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=2; total time=   1.6s
# [CV 4/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=2; total time=   1.7s
# [CV 5/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=2; total time=   1.8s
# [CV 1/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=3; total time=   1.5s
# [CV 2/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=3; total time=   1.5s
# [CV 3/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=3; total time=   1.5s
# [CV 4/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=3; total time=   1.7s
# [CV 5/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=3; total time=   1.8s
# [CV 1/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=4; total time=   1.4s
# [CV 2/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=4; total time=   1.3s
# [CV 3/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=4; total time=   1.4s
# [CV 4/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 5/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 1/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 2/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 3/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 4/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 5/5] END criterion=mse, max_depth=12, max_features=auto, min_samples_leaf=5; total time=   1.6s
# [CV 1/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=2; total time=   0.6s
# [CV 3/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=2; total time=   0.6s
# [CV 4/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=2; total time=   0.6s
# [CV 5/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=3; total time=   0.6s
# [CV 3/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=3; total time=   0.6s
# [CV 1/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=4; total time=   0.6s
# [CV 2/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=4; total time=   0.8s
# [CV 3/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=4; total time=   0.6s
# [CV 4/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=4; total time=   0.6s
# [CV 5/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 2/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=5; total time=   0.8s
# [CV 3/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 4/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=12, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 1/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=2; total time=   1.6s
# [CV 2/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=2; total time=   1.6s
# [CV 3/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=2; total time=   1.7s
# [CV 4/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=2; total time=   1.7s
# [CV 5/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=2; total time=   1.6s
# [CV 1/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=3; total time=   1.5s
# [CV 2/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=3; total time=   1.5s
# [CV 3/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=3; total time=   1.5s
# [CV 4/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=3; total time=   1.5s
# [CV 5/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=3; total time=   1.5s
# [CV 1/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=4; total time=   1.4s
# [CV 2/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 3/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=4; total time=   1.4s
# [CV 4/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=4; total time=   1.4s
# [CV 5/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 1/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 2/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 3/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 4/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 5/5] END criterion=mse, max_depth=13, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 1/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 4/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=4; total time=   1.0s
# [CV 3/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=4; total time=   0.8s
# [CV 1/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=5; total time=   0.8s
# [CV 2/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=13, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=2; total time=   1.6s
# [CV 2/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=2; total time=   1.7s
# [CV 3/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=2; total time=   1.7s
# [CV 4/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=2; total time=   1.7s
# [CV 5/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=2; total time=   1.7s
# [CV 1/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=3; total time=   1.5s
# [CV 2/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=3; total time=   1.7s
# [CV 3/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=3; total time=   1.6s
# [CV 4/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=3; total time=   1.6s
# [CV 5/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=3; total time=   1.5s
# [CV 1/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=4; total time=   1.6s
# [CV 2/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 3/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=4; total time=   1.6s
# [CV 4/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 5/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 1/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 2/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 3/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 4/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=5; total time=   1.6s
# [CV 5/5] END criterion=mse, max_depth=14, max_features=auto, min_samples_leaf=5; total time=   1.6s
# [CV 1/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 2/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=3; total time=   0.6s
# [CV 3/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=4; total time=   0.6s
# [CV 4/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=4; total time=   0.6s
# [CV 1/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 2/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 3/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 5/5] END criterion=mse, max_depth=14, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 1/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=2; total time=   1.7s
# [CV 2/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=2; total time=   1.7s
# [CV 3/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=2; total time=   1.8s
# [CV 4/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=2; total time=   1.8s
# [CV 5/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=2; total time=   1.7s
# [CV 1/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=3; total time=   1.7s
# [CV 2/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=3; total time=   1.7s
# [CV 3/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=3; total time=   1.6s
# [CV 4/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=3; total time=   1.6s
# [CV 5/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=3; total time=   1.6s
# [CV 1/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 2/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 3/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 4/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 5/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=4; total time=   1.6s
# [CV 1/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 2/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 3/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=5; total time=   1.7s
# [CV 4/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=5; total time=   1.6s
# [CV 5/5] END criterion=mse, max_depth=15, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 1/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 3/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 4/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=3; total time=   0.8s
# [CV 2/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=4; total time=   0.6s
# [CV 2/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=4; total time=   0.6s
# [CV 1/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=5; total time=   0.8s
# [CV 3/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 4/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=15, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=2; total time=   1.9s
# [CV 2/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=2; total time=   1.7s
# [CV 3/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=2; total time=   1.8s
# [CV 4/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=2; total time=   1.8s
# [CV 5/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=2; total time=   1.8s
# [CV 1/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=3; total time=   1.7s
# [CV 2/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=3; total time=   1.6s
# [CV 3/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=3; total time=   1.7s
# [CV 4/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=3; total time=   1.6s
# [CV 5/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=3; total time=   1.6s
# [CV 1/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 2/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 3/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 4/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=4; total time=   1.7s
# [CV 5/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=4; total time=   1.6s
# [CV 1/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 2/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 3/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=5; total time=   1.6s
# [CV 4/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 5/5] END criterion=mse, max_depth=16, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 1/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 3/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 4/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 5/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 1/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=4; total time=   0.6s
# [CV 2/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=4; total time=   0.6s
# [CV 3/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=4; total time=   0.6s
# [CV 4/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 2/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 4/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 5/5] END criterion=mse, max_depth=16, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=2; total time=   2.1s
# [CV 2/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=2; total time=   1.9s
# [CV 3/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=2; total time=   1.8s
# [CV 4/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=2; total time=   1.7s
# [CV 5/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=2; total time=   2.0s
# [CV 1/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=3; total time=   1.9s
# [CV 2/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=3; total time=   1.8s
# [CV 3/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=3; total time=   1.7s
# [CV 4/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=3; total time=   1.6s
# [CV 5/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=3; total time=   2.4s
# [CV 1/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=4; total time=   2.1s
# [CV 2/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=4; total time=   1.8s
# [CV 3/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=4; total time=   1.6s
# [CV 4/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=4; total time=   1.7s
# [CV 5/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=4; total time=   1.7s
# [CV 1/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 2/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 3/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 4/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 5/5] END criterion=mse, max_depth=17, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 1/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=2; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=4; total time=   0.8s
# [CV 3/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=4; total time=   0.8s
# [CV 1/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 2/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=5; total time=   0.8s
# [CV 4/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=5; total time=   0.8s
# [CV 5/5] END criterion=mse, max_depth=17, max_features=sqrt, min_samples_leaf=5; total time=   0.6s
# [CV 1/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=2; total time=   1.8s
# [CV 2/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=2; total time=   1.9s
# [CV 3/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=2; total time=   2.1s
# [CV 4/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=2; total time=   1.9s
# [CV 5/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=2; total time=   1.9s
# [CV 1/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=3; total time=   2.3s
# [CV 2/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=3; total time=   1.9s
# [CV 3/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=3; total time=   1.6s
# [CV 4/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=3; total time=   1.7s
# [CV 5/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=3; total time=   1.7s
# [CV 1/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 2/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 3/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 4/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 5/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=4; total time=   1.6s
# [CV 1/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=5; total time=   1.4s
# [CV 2/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 3/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 4/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 5/5] END criterion=mse, max_depth=18, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 1/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 2/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 3/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 4/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 5/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 1/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 3/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=18, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=2; total time=   1.8s
# [CV 2/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=2; total time=   1.8s
# [CV 3/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=2; total time=   1.8s
# [CV 4/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=2; total time=   1.8s
# [CV 5/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=2; total time=   1.8s
# [CV 1/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=3; total time=   1.6s
# [CV 2/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=3; total time=   1.7s
# [CV 3/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=3; total time=   1.6s
# [CV 4/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=3; total time=   1.7s
# [CV 5/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=3; total time=   1.7s
# [CV 1/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 2/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=4; total time=   1.5s
# [CV 3/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=4; total time=   1.6s
# [CV 4/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=4; total time=   1.6s
# [CV 5/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=4; total time=   1.6s
# [CV 1/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 2/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 3/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 4/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 5/5] END criterion=mse, max_depth=19, max_features=auto, min_samples_leaf=5; total time=   1.5s
# [CV 1/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 2/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 3/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=2; total time=   0.9s
# [CV 4/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 5/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=2; total time=   0.8s
# [CV 1/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=3; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=3; total time=   0.8s
# [CV 3/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=3; total time=   0.9s
# [CV 4/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=3; total time=   0.8s
# [CV 5/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=3; total time=   0.8s
# [CV 1/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 2/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=4; total time=   0.8s
# [CV 3/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 5/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=4; total time=   0.7s
# [CV 1/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=5; total time=   0.8s
# [CV 2/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=5; total time=   0.9s
# [CV 3/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=5; total time=   0.7s
# [CV 4/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=5; total time=   0.8s
# [CV 5/5] END criterion=mse, max_depth=19, max_features=sqrt, min_samples_leaf=5; total time=   0.8s
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['mse'], 'max_depth': range(10, 20),
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': range(2, 6)},
#              verbose=3)

# %%
gridSearchCV.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 19,
#  'max_features': 'auto',
#  'min_samples_leaf': 2}

# %%
y_pred = gridSearchCV.best_estimator_.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7365317902092343

# %%
# saving the model

# %%
joblib.dump(gridSearchCV.best_estimator_,'RandomForestRegressor.modal')
# Out:
# ['RandomForestRegressor.modal']
