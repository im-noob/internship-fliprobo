# %%
import json
import os
import pandas as pd
from datetime import datetime, timedelta
from time import sleep
from itertools import combinations
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.by import By

from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException

# %%
# # Comman function for init driver
# def init_driver(url):
#     driver = webdriver.Chrome(executable_path=CHROMEDRIVER_PATH)
#     driver.maximize_window()
#     driver.get('https://paytm.com/flights')
#     driver.get(url)
#     return driver

## https://stackoverflow.com/questions/53039551/selenium-webdriver-modifying-navigator-webdriver-flag-to-prevent-selenium-detec
def init_driver(url):
    chrome_options = webdriver.ChromeOptions()
    chrome_options.add_argument('--disable-blink-features=AutomationControlled')
    chrome_options.add_experimental_option("excludeSwitches", ["enable-automation"])
    chrome_options.add_experimental_option('useAutomationExtension', False)
    driver = webdriver.Chrome(executable_path=CHROMEDRIVER_PATH,options=chrome_options)
    driver.maximize_window()
    try:
        driver.get(url)
    except:
        print('error 4')
            
    return driver


def wait_for_page_load(xpath_url):
    global driver
    try:
        element_present = EC.presence_of_element_located((By.XPATH, xpath_url))
        WebDriverWait(driver, 5).until(element_present)
        return True
    except TimeoutException:
        print("Timed out waiting for page to load")
        try:
            driver.close()
        except:
            driver = init_driver(url)
            print('driver not found')
            
        # sleep(2)
        
        return False
    except NoSuchElementException:
        print("Element not found")
        return False

# %%
print('Starting...')
url = 'https://paytm.com/flights'
CHROMEDRIVER_PATH = './chromedriver'
WINDOW_SIZE = "1920,1080"
chrome_options = Options()
# chrome_options.headless = True
# chrome_options.add_argument("--headless")
# chrome_options.add_argument("--window-size=%s" % WINDOW_SIZE)
# chrome_options.add_argument('--user-data-dir=./User_Data')
chrome_options.add_argument('--disable-blink-features=AutomationControlled')
chrome_options.add_experimental_option("useAutomationExtension", False)
chrome_options.add_experimental_option("excludeSwitches",["enable-automation"])
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
# chrome_options.add_argument("--disable-gpu")
# chrome_options.add_argument("--remote-debugging-port=9222")
# chrome_options.add_experimental_option("excludeSwitches",["ignore-certificate-errors"])

print('initiated...')

preferences = {
	# "profile.default_content_settings.popups": 0,
	"download.default_directory": os.getcwd() + os.path.sep,
	# "directory_upgrade": True
}

chrome_options.add_experimental_option('prefs', preferences)

# chrome_options.binary_location = CHROME_PATH

driver = webdriver.Chrome(executable_path=CHROMEDRIVER_PATH, options=chrome_options)
driver.maximize_window()


driver.get(url)
# Out:
# Starting...
# initiated...

# %%
#1500

# %%
pd.options.display.max_rows = 100

# %%
# all city list
citys = [
    'DEL-Delhi',
    'BOM-Mumbai',
    'BLR-Bengaluru',
    'HYD-Hyderabad',
    'CU-Kolkata',
    'MAA-Chennai',
    'AMD-Ahmedabad',
    'GOI-Goa',
    'PAT-Patna',
    'COK-Kochi',
    'LKO-Lucknow',
    'GAU-Guwahati',
    'PNQ-Pune',
    'JAI-Jaipur',
    'SXR-Srinagar',
    'BBI-Bhubaneshwar',
    'IXB-Bagdogra',
    'VNS-Varanasi',
    'IXC-Chandigarh',
    'IXR-Ranchi',
    'VTZ-Vishakhapatnam',
    'RPR-Raipur',
    'NAG-Nagpur',
    'TRV-Thiruvananthapuram',
    'CCJ-Kozhikode',
    'IDR-Indore',
    'ATQ-Amritsar',
    'IXJ-Jammu',
    'CJB-Coimbatore',
    'DED-Dehradun',
]

# %%
possible_combinations = list(combinations(citys,2))

# %%
def collect_data(driver, today, next_date, day_before):
    
    wait_for_page_load('//div[@class="_2JLq"]/div[@class="_2TFk"]')
    wait_for_page_load('//div[@class="_3H-S _1Eia"]')
    
    all_boxes = driver.find_elements_by_xpath('//div[@class="_2JLq"]/div[@class="_2TFk"]')
    try:
        for one_box in all_boxes:
            try:
                flight_name = one_box.find_element_by_xpath('.//div[@class="_3H-S _1Eia"]').text
                flight_id = one_box.find_element_by_xpath('.//div[@class="NqXj _2GoO"]').text
                start_time = one_box.find_element_by_xpath('.//div[@class="_3H-S"]').text
                end_time = one_box.find_element_by_xpath('.//div[@class="_3H-S _1wD5"]').text.split('\n')[0]
                travel_time = one_box.find_element_by_xpath('.//div[@class="vY4t"]').text
                stops = one_box.find_element_by_xpath('.//div[@class="_7BOG"]').text
                fare = one_box.find_element_by_xpath('.//div[@class="_1cxG"]').text

                all_data.append({
                    'flight_name': flight_name,
                    'flight_id': flight_id,
                    'start_time': start_time,
                    'end_time': end_time,
                    'travel_time': travel_time,
                    'stops': stops,
                    'fare': fare,
#                     'today': today,
#                     'next_date': next_date,
#                     'day_before': day_before
                })
            except Exception as e:
                print(e)
                print('error2')
                # sleep(5)
            
    except Exception as e:
        print(e)
        print('error3')
        # sleep(5)

# %%
def search_page(driver, source, destination):
    
    try:
        clear_inputs = driver.find_elements_by_xpath('//div[@class="fl-input-clear"]')
        clear_inputs[0].click()
        clear_inputs[1].click()
    except:
        print('cleared already')
        
    sleep(2)
    wait_for_page_load('//div[@class="_31PN"]//input')
    
    inputs = driver.find_elements_by_xpath('//div[@class="_31PN"]//input')

    start_input = inputs[0]
    end_input = inputs[1]

    start_input.clear()
    start_input.send_keys(source)
    sleep(2)
    wait_for_page_load('//div[@class="_2Alu"]//div[@class="_2xgL"]')
    # Select First suggestion
    driver.find_element_by_xpath('//div[@class="_2Alu"]//div[@class="_2xgL"]').click()

    end_input.clear()
    end_input.send_keys(destination)
    sleep(2)
    
    wait_for_page_load('//div[@class="_2Alu"]//div[@class="_2xgL"]')
    # Select First suggestion
    driver.find_element_by_xpath('//div[@class="_2Alu"]//div[@class="_2xgL"]').click()

    driver.find_element_by_xpath("//button[text()='Search']").click()
    sleep(2)

# %%
all_data = []
for i, one_combination in enumerate(possible_combinations):
    source, destination = one_combination
    today = datetime.today()
#     for i in range(1, 11):
    try:
        next_date = today.strftime('%Y-%m-%d') # (today + timedelta(i)).strftime('%Y-%m-%d')
        # url = f'https://paytm.com/flights/flightSearch/{source}/{destination}/1/0/0/E/{next_date}'
        # driver.get(url)
        search_page(driver, source, destination)
        sleep(2)
        collect_data(driver, today, next_date, 0)
    except Exception as e:
        # sleep(2)
        print(e)
        print('error1')
        try:
            driver.close()
        except:
            print('driver not found')
            
        driver = init_driver(url)
        
    print(one_combination, i+1, len(possible_combinations), (i+1)/ len(possible_combinations))
df = pd.DataFrame(all_data)
df
# Out:
# cleared already
# ('DEL-Delhi', 'BOM-Mumbai') 1 435 0.0022988505747126436
# ('DEL-Delhi', 'BLR-Bengaluru') 2 435 0.004597701149425287
# ('DEL-Delhi', 'HYD-Hyderabad') 3 435 0.006896551724137931
# ('DEL-Delhi', 'CU-Kolkata') 4 435 0.009195402298850575
# ('DEL-Delhi', 'MAA-Chennai') 5 435 0.011494252873563218
# ('DEL-Delhi', 'AMD-Ahmedabad') 6 435 0.013793103448275862
# ('DEL-Delhi', 'GOI-Goa') 7 435 0.016091954022988506
# ('DEL-Delhi', 'PAT-Patna') 8 435 0.01839080459770115
# ('DEL-Delhi', 'COK-Kochi') 9 435 0.020689655172413793
# ('DEL-Delhi', 'LKO-Lucknow') 10 435 0.022988505747126436
# ('DEL-Delhi', 'GAU-Guwahati') 11 435 0.02528735632183908
# ('DEL-Delhi', 'PNQ-Pune') 12 435 0.027586206896551724
# ('DEL-Delhi', 'JAI-Jaipur') 13 435 0.029885057471264367
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('DEL-Delhi', 'SXR-Srinagar') 14 435 0.03218390804597701
# cleared already
# ('DEL-Delhi', 'BBI-Bhubaneshwar') 15 435 0.034482758620689655
# ('DEL-Delhi', 'IXB-Bagdogra') 16 435 0.0367816091954023
# ('DEL-Delhi', 'VNS-Varanasi') 17 435 0.03908045977011494
# ('DEL-Delhi', 'IXC-Chandigarh') 18 435 0.041379310344827586
# ('DEL-Delhi', 'IXR-Ranchi') 19 435 0.04367816091954023
# ('DEL-Delhi', 'VTZ-Vishakhapatnam') 20 435 0.04597701149425287
# ('DEL-Delhi', 'RPR-Raipur') 21 435 0.04827586206896552
# ('DEL-Delhi', 'NAG-Nagpur') 22 435 0.05057471264367816
# ('DEL-Delhi', 'TRV-Thiruvananthapuram') 23 435 0.052873563218390804
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# error 4
# ('DEL-Delhi', 'CCJ-Kozhikode') 24 435 0.05517241379310345
# cleared already
# ('DEL-Delhi', 'IDR-Indore') 25 435 0.05747126436781609
# ('DEL-Delhi', 'ATQ-Amritsar') 26 435 0.059770114942528735
# ('DEL-Delhi', 'IXJ-Jammu') 27 435 0.06206896551724138
# ('DEL-Delhi', 'CJB-Coimbatore') 28 435 0.06436781609195402
# ('DEL-Delhi', 'DED-Dehradun') 29 435 0.06666666666666667
# ('BOM-Mumbai', 'BLR-Bengaluru') 30 435 0.06896551724137931
# ('BOM-Mumbai', 'HYD-Hyderabad') 31 435 0.07126436781609195
# ('BOM-Mumbai', 'CU-Kolkata') 32 435 0.0735632183908046
# ('BOM-Mumbai', 'MAA-Chennai') 33 435 0.07586206896551724
# ('BOM-Mumbai', 'AMD-Ahmedabad') 34 435 0.07816091954022988
# ('BOM-Mumbai', 'GOI-Goa') 35 435 0.08045977011494253
# ('BOM-Mumbai', 'PAT-Patna') 36 435 0.08275862068965517
# ('BOM-Mumbai', 'COK-Kochi') 37 435 0.08505747126436781
# ('BOM-Mumbai', 'LKO-Lucknow') 38 435 0.08735632183908046
# ('BOM-Mumbai', 'GAU-Guwahati') 39 435 0.0896551724137931
# ('BOM-Mumbai', 'PNQ-Pune') 40 435 0.09195402298850575
# ('BOM-Mumbai', 'JAI-Jaipur') 41 435 0.09425287356321839
# ('BOM-Mumbai', 'SXR-Srinagar') 42 435 0.09655172413793103
# ('BOM-Mumbai', 'BBI-Bhubaneshwar') 43 435 0.09885057471264368
# ('BOM-Mumbai', 'IXB-Bagdogra') 44 435 0.10114942528735632
# ('BOM-Mumbai', 'VNS-Varanasi') 45 435 0.10344827586206896
# ('BOM-Mumbai', 'IXC-Chandigarh') 46 435 0.10574712643678161
# ('BOM-Mumbai', 'IXR-Ranchi') 47 435 0.10804597701149425
# ('BOM-Mumbai', 'VTZ-Vishakhapatnam') 48 435 0.1103448275862069
# ('BOM-Mumbai', 'RPR-Raipur') 49 435 0.11264367816091954
# ('BOM-Mumbai', 'NAG-Nagpur') 50 435 0.11494252873563218
# ('BOM-Mumbai', 'TRV-Thiruvananthapuram') 51 435 0.11724137931034483
# ('BOM-Mumbai', 'CCJ-Kozhikode') 52 435 0.11954022988505747
# ('BOM-Mumbai', 'IDR-Indore') 53 435 0.12183908045977011
# ('BOM-Mumbai', 'ATQ-Amritsar') 54 435 0.12413793103448276
# ('BOM-Mumbai', 'IXJ-Jammu') 55 435 0.12643678160919541
# ('BOM-Mumbai', 'CJB-Coimbatore') 56 435 0.12873563218390804
# ('BOM-Mumbai', 'DED-Dehradun') 57 435 0.1310344827586207
# ('BLR-Bengaluru', 'HYD-Hyderabad') 58 435 0.13333333333333333
# ('BLR-Bengaluru', 'CU-Kolkata') 59 435 0.135632183908046
# ('BLR-Bengaluru', 'MAA-Chennai') 60 435 0.13793103448275862
# ('BLR-Bengaluru', 'AMD-Ahmedabad') 61 435 0.14022988505747128
# ('BLR-Bengaluru', 'GOI-Goa') 62 435 0.1425287356321839
# ('BLR-Bengaluru', 'PAT-Patna') 63 435 0.14482758620689656
# ('BLR-Bengaluru', 'COK-Kochi') 64 435 0.1471264367816092
# ('BLR-Bengaluru', 'LKO-Lucknow') 65 435 0.14942528735632185
# ('BLR-Bengaluru', 'GAU-Guwahati') 66 435 0.15172413793103448
# ('BLR-Bengaluru', 'PNQ-Pune') 67 435 0.15402298850574714
# ('BLR-Bengaluru', 'JAI-Jaipur') 68 435 0.15632183908045977
# ('BLR-Bengaluru', 'SXR-Srinagar') 69 435 0.15862068965517243
# ('BLR-Bengaluru', 'BBI-Bhubaneshwar') 70 435 0.16091954022988506
# ('BLR-Bengaluru', 'IXB-Bagdogra') 71 435 0.1632183908045977
# ('BLR-Bengaluru', 'VNS-Varanasi') 72 435 0.16551724137931034
# ('BLR-Bengaluru', 'IXC-Chandigarh') 73 435 0.167816091954023
# ('BLR-Bengaluru', 'IXR-Ranchi') 74 435 0.17011494252873563
# ('BLR-Bengaluru', 'VTZ-Vishakhapatnam') 75 435 0.1724137931034483
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('BLR-Bengaluru', 'RPR-Raipur') 76 435 0.17471264367816092
# cleared already
# ('BLR-Bengaluru', 'NAG-Nagpur') 77 435 0.17701149425287357
# ('BLR-Bengaluru', 'TRV-Thiruvananthapuram') 78 435 0.1793103448275862
# ('BLR-Bengaluru', 'CCJ-Kozhikode') 79 435 0.18160919540229886
# ('BLR-Bengaluru', 'IDR-Indore') 80 435 0.1839080459770115
# ('BLR-Bengaluru', 'ATQ-Amritsar') 81 435 0.18620689655172415
# ('BLR-Bengaluru', 'IXJ-Jammu') 82 435 0.18850574712643678
# ('BLR-Bengaluru', 'CJB-Coimbatore') 83 435 0.19080459770114944
# ('BLR-Bengaluru', 'DED-Dehradun') 84 435 0.19310344827586207
# ('HYD-Hyderabad', 'CU-Kolkata') 85 435 0.19540229885057472
# ('HYD-Hyderabad', 'MAA-Chennai') 86 435 0.19770114942528735
# ('HYD-Hyderabad', 'AMD-Ahmedabad') 87 435 0.2
# ('HYD-Hyderabad', 'GOI-Goa') 88 435 0.20229885057471264
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# 
# ('AMD-Ahmedabad', 'PNQ-Pune') 165 435 0.3793103448275862
# ('AMD-Ahmedabad', 'JAI-Jaipur') 166 435 0.3816091954022989
# ('AMD-Ahmedabad', 'SXR-Srinagar') 167 435 0.3839080459770115
# ('AMD-Ahmedabad', 'BBI-Bhubaneshwar') 168 435 0.38620689655172413
# ('AMD-Ahmedabad', 'IXB-Bagdogra') 169 435 0.38850574712643676
# ('AMD-Ahmedabad', 'VNS-Varanasi') 170 435 0.39080459770114945
# ('AMD-Ahmedabad', 'IXC-Chandigarh') 171 435 0.3931034482758621
# ('AMD-Ahmedabad', 'IXR-Ranchi') 172 435 0.3954022988505747
# ('AMD-Ahmedabad', 'VTZ-Vishakhapatnam') 173 435 0.39770114942528734
# ('AMD-Ahmedabad', 'RPR-Raipur') 174 435 0.4
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('AMD-Ahmedabad', 'NAG-Nagpur') 175 435 0.40229885057471265
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('AMD-Ahmedabad', 'TRV-Thiruvananthapuram') 176 435 0.4045977011494253
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('AMD-Ahmedabad', 'CCJ-Kozhikode') 177 435 0.4068965517241379
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('AMD-Ahmedabad', 'IDR-Indore') 178 435 0.4091954022988506
# cleared already
# ('AMD-Ahmedabad', 'ATQ-Amritsar') 179 435 0.4114942528735632
# ('AMD-Ahmedabad', 'IXJ-Jammu') 180 435 0.41379310344827586
# ('AMD-Ahmedabad', 'CJB-Coimbatore') 181 435 0.4160919540229885
# ('AMD-Ahmedabad', 'DED-Dehradun') 182 435 0.41839080459770117
# ('GOI-Goa', 'PAT-Patna') 183 435 0.4206896551724138
# ('GOI-Goa', 'COK-Kochi') 184 435 0.42298850574712643
# ('GOI-Goa', 'LKO-Lucknow') 185 435 0.42528735632183906
# ('GOI-Goa', 'GAU-Guwahati') 186 435 0.42758620689655175
# ('GOI-Goa', 'PNQ-Pune') 187 435 0.4298850574712644
# ('GOI-Goa', 'JAI-Jaipur') 188 435 0.432183908045977
# ('GOI-Goa', 'SXR-Srinagar') 189 435 0.43448275862068964
# ('GOI-Goa', 'BBI-Bhubaneshwar') 190 435 0.4367816091954023
# ('GOI-Goa', 'IXB-Bagdogra') 191 435 0.43908045977011495
# ('GOI-Goa', 'VNS-Varanasi') 192 435 0.4413793103448276
# ('GOI-Goa', 'IXC-Chandigarh') 193 435 0.4436781609195402
# ('GOI-Goa', 'IXR-Ranchi') 194 435 0.4459770114942529
# ('GOI-Goa', 'VTZ-Vishakhapatnam') 195 435 0.4482758620689655
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('GOI-Goa', 'RPR-Raipur') 196 435 0.45057471264367815
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('GOI-Goa', 'NAG-Nagpur') 197 435 0.4528735632183908
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('GOI-Goa', 'TRV-Thiruvananthapuram') 198 435 0.45517241379310347
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('GOI-Goa', 'CCJ-Kozhikode') 199 435 0.4574712643678161
# cleared already
# ('GOI-Goa', 'IDR-Indore') 200 435 0.45977011494252873
# ('GOI-Goa', 'ATQ-Amritsar') 201 435 0.46206896551724136
# ('GOI-Goa', 'IXJ-Jammu') 202 435 0.46436781609195404
# ('GOI-Goa', 'CJB-Coimbatore') 203 435 0.4666666666666667
# ('GOI-Goa', 'DED-Dehradun') 204 435 0.4689655172413793
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('PAT-Patna', 
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('NAG-Nagpur', 'IXJ-Jammu') 412 435 0.9471264367816092
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('NAG-Nagpur', 'CJB-Coimbatore') 413 435 0.9494252873563218
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('NAG-Nagpur', 'DED-Dehradun') 414 435 0.9517241379310345
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('TRV-Thiruvananthapuram', 'CCJ-Kozhikode') 415 435 0.9540229885057471
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('TRV-Thiruvananthapuram', 'IDR-Indore') 416 435 0.9563218390804598
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('TRV-Thiruvananthapuram', 'ATQ-Amritsar') 417 435 0.9586206896551724
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('TRV-Thiruvananthapuram', 'IXJ-Jammu') 418 435 0.960919540229885
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('TRV-Thiruvananthapuram', 'CJB-Coimbatore') 419 435 0.9632183908045977
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('TRV-Thiruvananthapuram', 'DED-Dehradun') 420 435 0.9655172413793104
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('CCJ-Kozhikode', 'IDR-Indore') 421 435 0.967816091954023
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('CCJ-Kozhikode', 'ATQ-Amritsar') 422 435 0.9701149425287356
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('CCJ-Kozhikode', 'IXJ-Jammu') 423 435 0.9724137931034482
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('CCJ-Kozhikode', 'CJB-Coimbatore') 424 435 0.9747126436781609
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('CCJ-Kozhikode', 'DED-Dehradun') 425 435 0.9770114942528736
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('IDR-Indore', 'ATQ-Amritsar') 426 435 0.9793103448275862
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('IDR-Indore', 'IXJ-Jammu') 427 435 0.9816091954022989
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('IDR-Indore', 'CJB-Coimbatore') 428 435 0.9839080459770115
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('IDR-Indore', 'DED-Dehradun') 429 435 0.9862068965517241
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('ATQ-Amritsar', 'IXJ-Jammu') 430 435 0.9885057471264368
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('ATQ-Amritsar', 'CJB-Coimbatore') 431 435 0.9908045977011494
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('ATQ-Amritsar', 'DED-Dehradun') 432 435 0.993103448275862
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('IXJ-Jammu', 'CJB-Coimbatore') 433 435 0.9954022988505747
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('IXJ-Jammu', 'DED-Dehradun') 434 435 0.9977011494252873
# cleared already
# Timed out waiting for page to load
# Message: invalid session id
#
# error1
# driver not found
# ('CJB-Coimbatore', 'DED-Dehradun') 435 435 1.0
#      flight_name  flight_id start_time end_time travel_time  \
# 0       Go First   G8 - 354      22:30    00:40      2h 10m
# 1       Go First   G8 - 323      18:45    21:05      2h 20m
# 2       Go First   G8 - 717      19:45    08:25     12h 40m
# 3        Vistara   UK - 981      21:40    23:50      2h 10m
# 4         IndiGo  6E - 2137      23:35    01:45      2h 10m
# ...          ...        ...        ...      ...         ...
# 1885      IndiGo   6E - 547      22:30    07:05      8h 35m
# 1886      IndiGo   6E - 122      23:35    08:15      8h 40m
# 1887      IndiGo   6E - 122      23:35    08:55      9h 20m
# 1888    Go First  G8 - 2608      21:15    07:30     10h 15m
# 1889    Go First  G8 - 2608      21:15    11:25     14h 10m
#
#                     stops    fare
# 0                Non Stop   5,954
# 1                Non Stop   5,954
# 2     1 stop at Ahmedabad   5,954
# 3                Non Stop   5,955
# 4                Non Stop   5,955
# ...                   ...     ...
# 1885  1 stop at Ahmedabad   7,260
# 1886  1 stop at Hyderabad   8,006
# 1887  1 stop at Hyderabad   8,321
# 1888     1 stop at Mumbai  10,855
# 1889     1 stop at Mumbai  10,855
#
# [1890 rows x 7 columns]

# %%
df.to_csv('flight_data_.csv')
