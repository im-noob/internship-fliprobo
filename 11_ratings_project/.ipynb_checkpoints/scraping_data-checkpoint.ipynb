# %%
import pandas as pd
import os
from time import sleep
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By

# %%
CHROMEDRIVER_PATH = './chromedriver'
WINDOW_SIZE = "1920,1080"

# %%
# Comman function for init driver
def init_driver(url):
    driver = webdriver.Chrome(executable_path=CHROMEDRIVER_PATH)
    driver.maximize_window()
    driver.get(url)
    return driver

# %%
def wait_for_page_load(xpath_url):
    try:
        element_present = EC.presence_of_element_located((By.XPATH, xpath_url))
        WebDriverWait(driver, 5).until(element_present)
    except TimeoutException:
        print("Timed out waiting for page to load")
    except NoSuchElementException:
        print("Element not found")

# %%
product_ids = [
    'B08N5XSG8Z',
    'B09JR8RKNN',
    'B08N5VSQNG',
    'B08T6THSMQ',
    'B08N5WRWNW',
    'B08CRMTKMK',
    'B08696XB4B',
    'B08444SXZ6',
    'B07YYNX5X6',
    'B08444S68L',
    'B09GFPVD9Y',
    'B08XJGNQS7',
    'B09GFNZT24',
    'B08697N43G',
    'B07PR1CL3S',
    'B0856HNMR7',
    'B0856HY85J',
    'B06Y5LK5QJ',
    'B0856HRTJG',
    'B0873L7J6X',
    'B08SFFP19B',
    'B07TXVLB1G',
    'B07LG59NPV',
    'B096VF5YYF',
    'B097R25DP7',
    'B07YY1BY5B',
    'B096VFND31',
    'B097R2JBDF',
    'B096VF1PJ8',
    'B08L13YPGZ',
    'B07RJWB548',
    'B083YL2MYZ',
    'B07BS4TJ43',
    'B08LHJ9TF4',
    'B07BRR59DT',
    'B07GWKDLGT',
    'B083V9RS56',
    'B00VT61IKA',
    'B08D9MNH4B',
    'B01JOFKL0A',
    'B08CYRBXYX',
    'B09N3LHV2X',
    'B08D9KB33V',
    'B01H25A1AE',
    'B07JDH2C8X',
    'B073NTCT4R',
    'B07S41XDX7',
    'B07JD7GKJP',
    'B08J82K4GX',
    'B073NTCT4Q',
    'B01GFPGHSM',
    'B07W41VQ91',
    'B071XCQ2PZ',
    'B07J247XFL',
    'B07DTF9Y7M',
    'B01I054Y94',
    'B07ZZBYWKF',
    'B07GVR9TG7',
    'B01HGCLUH6',
    'B0759QMF85',
    'B07JQ7157K',
    'B095K48F52',
    'B0085IATT6',
    'B071RSD473',
    'B07DYWS92W',
    'B07W9KYT62',

]
# 6 records from each section total 54
five_ratings = [
    'five_star',
    'four_star',
    'three_star',
    'two_star',
    'one_star'
]
# https://www.amazon.in/product-reviews/B07BS4TJ43/

# %%
driver = init_driver('https://google.com')

# %%
final_data = [] 
def fetch_all_data():
    product_count = 0  
    while product_count < 75:
        sleep(5)
        # wait for page load
        wait_for_page_load('//div[@data-hook="review"]')    

        # finding top all boxes 
        all_box = driver.find_elements_by_xpath('//div[@data-hook="review"]') 

        # Ittrating over box to find details
        for one_box in all_box:

            try:
                rating = one_box.find_element_by_xpath('.//i/span[@class="a-icon-alt"]').get_attribute('innerHTML')
                review_summary = one_box.find_element_by_xpath('.//*[@data-hook="review-title"]').text
                full_review = one_box.find_element_by_xpath('.//span[@data-hook="review-body"]').text



                final_data.append({
                    'rating':rating,
                    'review_summary':review_summary,
                    'full_review':full_review,
                })

            except Exception as e:
                print(e)
                
            product_count += 1
            if product_count > 75:
                break
                
            
        # Go to next page
        sleep(5)
        try:
            driver.find_element_by_xpath('//li[@class="a-last"]').click()
        except Exception:
            break

    job_data = pd.DataFrame(final_data)
    job_data

# %%
total_len = len(product_ids)
for i, one_product_id in enumerate(product_ids):    
    review_url = f'https://www.amazon.in/product-reviews/{one_product_id}/'
 
    print('checking for: ', review_url,'-----' ,i,'/',total_len)
    # Goting to review page
    driver.get(review_url)
    
    # Setting Which ratting to be fetched
    for one_ratting in five_ratings:
        Select(driver.find_element_by_id('star-count-dropdown')).select_by_value(one_ratting)
        sleep(2)
        fetch_all_data()
# Out:
# checking for:  https://www.amazon.in/product-reviews/B08N5XSG8Z/ ----- 0 / 66
# checking for:  https://www.amazon.in/product-reviews/B09JR8RKNN/ ----- 1 / 66
# checking for:  https://www.amazon.in/product-reviews/B08N5VSQNG/ ----- 2 / 66
# checking for:  https://www.amazon.in/product-reviews/B08T6THSMQ/ ----- 3 / 66
# checking for:  https://www.amazon.in/product-reviews/B08N5WRWNW/ ----- 4 / 66
# checking for:  https://www.amazon.in/product-reviews/B08CRMTKMK/ ----- 5 / 66
# checking for:  https://www.amazon.in/product-reviews/B08696XB4B/ ----- 6 / 66
# checking for:  https://www.amazon.in/product-reviews/B08444SXZ6/ ----- 7 / 66
# checking for:  https://www.amazon.in/product-reviews/B07YYNX5X6/ ----- 8 / 66
# checking for:  https://www.amazon.in/product-reviews/B08444S68L/ ----- 9 / 66
# checking for:  https://www.amazon.in/product-reviews/B09GFPVD9Y/ ----- 10 / 66
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# checking for:  https://www.amazon.in/product-reviews/B08XJGNQS7/ ----- 11 / 66
# checking for:  https://www.amazon.in/product-reviews/B09GFNZT24/ ----- 12 / 66
# checking for:  https://www.amazon.in/product-reviews/B08697N43G/ ----- 13 / 66
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# checking for:  https://www.amazon.in/product-reviews/B07PR1CL3S/ ----- 14 / 66
# checking for:  https://www.amazon.in/product-reviews/B0856HNMR7/ ----- 15 / 66
# checking for:  https://www.amazon.in/product-reviews/B0856HY85J/ ----- 16 / 66
# checking for:  https://www.amazon.in/product-reviews/B06Y5LK5QJ/ ----- 17 / 66
# checking for:  https://www.amazon.in/product-reviews/B0856HRTJG/ ----- 18 / 66
# checking for:  https://www.amazon.in/product-reviews/B0873L7J6X/ ----- 19 / 66
# checking for:  https://www.amazon.in/product-reviews/B08SFFP19B/ ----- 20 / 66
# checking for:  https://www.amazon.in/product-reviews/B07TXVLB1G/ ----- 21 / 66
# checking for:  https://www.amazon.in/product-reviews/B07LG59NPV/ ----- 22 / 66
# checking for:  https://www.amazon.in/product-reviews/B096VF5YYF/ ----- 23 / 66
# checking for:  https://www.amazon.in/product-reviews/B097R25DP7/ ----- 24 / 66
# checking for:  https://www.amazon.in/product-reviews/B07YY1BY5B/ ----- 25 / 66
# checking for:  https://www.amazon.in/product-reviews/B096VFND31/ ----- 26 / 66
# checking for:  https://www.amazon.in/product-reviews/B097R2JBDF/ ----- 27 / 66
# checking for:  https://www.amazon.in/product-reviews/B096VF1PJ8/ ----- 28 / 66
# checking for:  https://www.amazon.in/product-reviews/B08L13YPGZ/ ----- 29 / 66
# checking for:  https://www.amazon.in/product-reviews/B07RJWB548/ ----- 30 / 66
# checking for:  https://www.amazon.in/product-reviews/B083YL2MYZ/ ----- 31 / 66
# checking for:  https://www.amazon.in/product-reviews/B07BS4TJ43/ ----- 32 / 66
# checking for:  https://www.amazon.in/product-reviews/B08LHJ9TF4/ ----- 33 / 66
# checking for:  https://www.amazon.in/product-reviews/B07BRR59DT/ ----- 34 / 66
# checking for:  https://www.amazon.in/product-reviews/B07GWKDLGT/ ----- 35 / 66
# checking for:  https://www.amazon.in/product-reviews/B083V9RS56/ ----- 36 / 66
# checking for:  https://www.amazon.in/product-reviews/B00VT61IKA/ ----- 37 / 66
# checking for:  https://www.amazon.in/product-reviews/B08D9MNH4B/ ----- 38 / 66
# checking for:  https://www.amazon.in/product-reviews/B01JOFKL0A/ ----- 39 / 66
# checking for:  https://www.amazon.in/product-reviews/B08CYRBXYX/ ----- 40 / 66
# checking for:  https://www.amazon.in/product-reviews/B09N3LHV2X/ ----- 41 / 66
# checking for:  https://www.amazon.in/product-reviews/B08D9KB33V/ ----- 42 / 66
# checking for:  https://www.amazon.in/product-reviews/B01H25A1AE/ ----- 43 / 66
# checking for:  https://www.amazon.in/product-reviews/B07JDH2C8X/ ----- 44 / 66
# checking for:  https://www.amazon.in/product-reviews/B073NTCT4R/ ----- 45 / 66
# checking for:  https://www.amazon.in/product-reviews/B07S41XDX7/ ----- 46 / 66
# checking for:  https://www.amazon.in/product-reviews/B07JD7GKJP/ ----- 47 / 66
# checking for:  https://www.amazon.in/product-reviews/B08J82K4GX/ ----- 48 / 66
# checking for:  https://www.amazon.in/product-reviews/B073NTCT4Q/ ----- 49 / 66
# checking for:  https://www.amazon.in/product-reviews/B01GFPGHSM/ ----- 50 / 66
# checking for:  https://www.amazon.in/product-reviews/B07W41VQ91/ ----- 51 / 66
# checking for:  https://www.amazon.in/product-reviews/B071XCQ2PZ/ ----- 52 / 66
# checking for:  https://www.amazon.in/product-reviews/B07J247XFL/ ----- 53 / 66
# checking for:  https://www.amazon.in/product-reviews/B07DTF9Y7M/ ----- 54 / 66
# checking for:  https://www.amazon.in/product-reviews/B01I054Y94/ ----- 55 / 66
# checking for:  https://www.amazon.in/product-reviews/B07ZZBYWKF/ ----- 56 / 66
# checking for:  https://www.amazon.in/product-reviews/B07GVR9TG7/ ----- 57 / 66
# checking for:  https://www.amazon.in/product-reviews/B01HGCLUH6/ ----- 58 / 66
# checking for:  https://www.amazon.in/product-reviews/B0759QMF85/ ----- 59 / 66
# checking for:  https://www.amazon.in/product-reviews/B07JQ7157K/ ----- 60 / 66
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
#
# checking for:  https://www.amazon.in/product-reviews/B095K48F52/ ----- 61 / 66
# checking for:  https://www.amazon.in/product-reviews/B0085IATT6/ ----- 62 / 66
# checking for:  https://www.amazon.in/product-reviews/B071RSD473/ ----- 63 / 66
# checking for:  https://www.amazon.in/product-reviews/B07DYWS92W/ ----- 64 / 66
# checking for:  https://www.amazon.in/product-reviews/B07W9KYT62/ ----- 65 / 66

# %%
job_data = pd.DataFrame(final_data)
job_data
# Out:
#                    rating                                     review_summary  \
# 0      5.0 out of 5 stars                                          THE BEST!
# 1      5.0 out of 5 stars                              It's alien technology
# 2      5.0 out of 5 stars                                      Super excited
# 3      5.0 out of 5 stars                          M1 8gb vs 16gb confusion?
# 4      5.0 out of 5 stars                                       Play awesome
# ...                   ...                                                ...
# 22320  1.0 out of 5 stars                                   Pls dont buy it.
# 22321  1.0 out of 5 stars       Wifi signal level is very poor comparing JIO
# 22322  1.0 out of 5 stars                      Not reliable. Useless Product
# 22323  1.0 out of 5 stars  Another router delivered of same company same ...
# 22324  1.0 out of 5 stars      Good Product with good features but poor life
#
#                                              full_review
# 0      Best in class. Performance, Display, Battery b...
# 1      Pros:-\n1. It's Superfast. It will feel fast o...
# 2      If we could get it for around 70-75k with some...
# 3      Should i buy the 16gb ram from apple store? Th...
# 4      Excellent product very fast and amazing fast m...
# ...                                                  ...
# 22320  Not worth of the price. Frequent signal drops....
# 22321  Please don't expect you will get good signal w...
# 22322  The WiFi signal is terrible. I bought it in Ju...
# 22323  The item shown is not exactly the same as deli...
# 22324  I purchased this on 15th Aug 20 & today on 3rd...
#
# [22325 rows x 3 columns]

# %%
job_data.to_csv('scraped_data.csv')
